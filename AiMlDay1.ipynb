# %% [markdown]
# <a href="https://colab.research.google.com/github/aadarsh0001/AiMlPractice/blob/main/AiMlDay1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assigment CSV Read

# %%
import pandas as pd

# %%
df=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv')

# %% [markdown]
# https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv
#
# https://github.com/YBI-Foundation/Dataset/blob/main/Titanic.csv

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# Assigment HTML Read

# %% [markdown]
# https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.html

# %%
import pandas as pd

# %%
hdf=pd.read_html('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.html')
hdf
# Out:
# [          0         1          2                            3       4      5   \
#  0     pclass  survived       name                          sex     age  sibsp
#  1          1         1      Allen       Miss. Elisabeth Walton  female     29
#  2          1         1    Allison        Master. Hudson Trevor    male   0.92
#  3          1         0    Allison          Miss. Helen Loraine  female      2
#  4          1         0    Allison  Mr. Hudson Joshua Creighton    male     30
#  ...      ...       ...        ...                          ...     ...    ...
#  1305       3         0     Zabour                 Miss. Hileni  female   14.5
#  1306       3         0     Zabour                Miss. Thamine  female    NaN
#  1307       3         0   Zakarian              Mr. Mapriededer    male   26.5
#  1308       3         0   Zakarian                    Mr. Ortin    male     27
#  1309       3         0  Zimmerman                      Mr. Leo    male     29
#
# ...

# %% [markdown]
# Assigment json Data read

# %%
import pandas as pds

# %% [markdown]
# https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.json

# %%
jdf=pds.read_json('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.json')
jdf
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# Assigment txt data read

# %% [markdown]
# https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.txt

# %%
import pandas as pd
tdf=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.txt')
tdf
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# Assigment xlsx file read
# https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.xlsx

# %%
import pandas as pd
xdf=pd.read_excel('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.xlsx')
xdf
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...
